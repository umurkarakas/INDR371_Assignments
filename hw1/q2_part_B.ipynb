# %%
import numpy as np
import pandas as pd
import gurobipy as gp
from gurobipy import GRB
from unidecode import unidecode

distance=pd.read_excel("Turkish network.xls",sheet_name="Distance (km)", skiprows=[0], index_col=1).iloc[:,1:]
travel_time=pd.read_excel("Turkish network.xls",sheet_name="Travel time (min)", skiprows=[0], index_col=1).iloc[:,1:]
flow = pd.read_excel("Turkish network.xls",sheet_name="Flow", skiprows=[0], index_col=1).iloc[:,1:]
fixed_link_cost = pd.read_excel("Turkish network.xls",sheet_name="Fixed link cost", skiprows=[0], index_col=1).iloc[:,1:]
fixed_hub_cost = pd.read_excel("Turkish network.xls", sheet_name="Fixed hub cost", index_col=1).iloc[:,1:]

cities = list(distance.columns)
cities = [unidecode(city) for city in cities]

distance.index = cities
distance.columns = cities

travel_time.index = cities
travel_time.columns = cities

flow.index = cities
flow.columns = cities

fixed_link_cost.index = cities
fixed_link_cost.columns = cities

fixed_hub_cost.index = cities
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/3c/7zgkbng12bl6ngq2h3glc2lw0000gn/T/ipykernel_60018/2863359415.py in <module>
#       1 import numpy as np
#       2 import pandas as pd
# ----> 3 import gurobipy as gp
#       4 from gurobipy import GRB
#       5 from unidecode import unidecode
#
# ModuleNotFoundError: No module named 'gurobipy'

# %%
fixed_hub_cost = dict(zip(cities, fixed_hub_cost.iloc[:,0]))
alpha = 0.5

# %%
def floyd(G):
    nV = len(G)
    dist = list(map(lambda p: list(map(lambda q: q, p)), G))

    # Adding vertices individually
    for r in range(nV):
        for p in range(nV):
            for q in range(nV):
                dist[p][q] = min(dist[p][q], dist[p][r] + dist[r][q])
    return dist

# %%
u = distance * fixed_link_cost / 1000
u_hub = alpha * pd.DataFrame(floyd(np.array(u)), index=cities, columns=cities)
possible_hubs = cities
o = np.sum(flow, axis=1)
o = dict(zip(o.index, o.values))

# %% [markdown]
# #### Solution adapted from:
# Andreas T. Ernst, Mohan Krishnamoorthy,
# Exact and heuristic algorithms for the uncapacitated multiple allocation p-hub median problem,
# European Journal of Operational Research,
# Volume 104, Issue 1,
# 1998,
# Pages 100-112,
# ISSN 0377-2217,
# https://doi.org/10.1016/S0377-2217(96)00340-2.
# (https://www.sciencedirect.com/science/article/pii/S0377221796003402)

# %% [markdown]
# ### Solution without shortest paths

# %%
#model
m = gp.Model("q2_part2")
m.ModelSense = GRB.MINIMIZE
#decision variables 
h=m.addVars(possible_hubs, name="h", vtype=GRB.BINARY)
x=m.addVars(cities, cities, possible_hubs, name="x",vtype=GRB.CONTINUOUS, lb = 0)
y=m.addVars(cities, possible_hubs, possible_hubs, name="y", vtype=GRB.CONTINUOUS, lb = 0)
z=m.addVars(cities, possible_hubs, name="z", vtype=GRB.CONTINUOUS, lb = 0)
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2023-10-08

# %%
hub_limit=m.addConstr(gp.quicksum(fixed_hub_cost[i]*h[i] for i in possible_hubs) <= 2400,"hub_cost_limit")

cons1 = m.addConstrs(
    (gp.quicksum(z[(i,k)] for k in possible_hubs) == o[i] for i in cities))

cons2 = m.addConstrs(
    (gp.quicksum(x[(i,j,l)] for l in possible_hubs) == flow.at[i,j] for i in cities for j in cities))

cons3 = m.addConstrs(
    (gp.quicksum(y[(i,k,l)] for l in possible_hubs) + 
     gp.quicksum(x[(i,j,k)] for j in cities) - 
     gp.quicksum(y[(i,l,k)] for l in possible_hubs) -
     z[(i,k)] == 0 for i in cities for k in possible_hubs))

cons4 = m.addConstrs(
    (z[(i,k)] <= o[i] * h[k] for i in cities for k in possible_hubs))

cons5 = m.addConstrs(
    (x[i,j,l] <= flow.at[i,j] * h[l] for i in cities for j in cities for l in possible_hubs))
    
m.setObjective(gp.quicksum(gp.quicksum(u.at[i,k] * z[(i,k)] for k in possible_hubs) + gp.quicksum(alpha*u.at[k,l]*y[(i,k,l)] for k in possible_hubs for l in possible_hubs) + gp.quicksum(u.at[l,j] * x[i,j,l] for l in possible_hubs for j in cities) for i in cities))

# %%
m.optimize()
# Out:
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 551206 rows, 1069524 columns and 3195288 nonzeros
# Model fingerprint: 0x0d792a4f
# Variable types: 1069443 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+07]
#   Objective range  [2e-04, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+07]
# Presolve removed 6642 rows and 13122 columns
# Presolve time: 3.39s
# Presolved: 544564 rows, 1056402 columns, 3175605 nonzeros
# Variable types: 1056321 continuous, 81 integer (81 binary)
#
# Deterministic concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Root barrier log...
#
# Ordering time: 0.36s
#
# Barrier statistics:
#  Dense cols : 81
#  AA' NZ     : 2.314e+06
#  Factor NZ  : 4.254e+06 (roughly 600 MB of memory)
#  Factor Ops : 3.825e+08 (less than 1 second per iteration)
#  Threads    : 5
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.70585089e+11 -1.28549022e+10  3.74e+05 5.77e-15  4.02e+05    11s
#    1   1.43306539e+11 -6.01143540e+09  3.13e+05 4.29e+01  2.97e+05    12s
#    2   6.29090761e+10 -3.77204500e+09  1.28e+05 2.06e+01  1.27e+05    13s
#    3   1.91320030e+10 -2.31348332e+09  3.07e+04 5.00e+00  3.39e+04    14s
#    4   3.68293928e+09 -1.64522976e+09  3.64e+03 1.40e+00  5.53e+03    14s
#    5   2.65959806e+09 -1.33079025e+09  2.49e+03 8.88e-01  3.73e+03    15s
#    6   2.11659591e+09 -1.04812959e+09  1.91e+03 5.51e-01  2.72e+03    16s
#    7   1.77193995e+09 -8.84153830e+08  1.56e+03 4.02e-01  2.16e+03    17s
#    8   1.13974854e+09 -6.88346964e+08  9.35e+02 2.56e-01  1.34e+03    17s
#    9   8.52792626e+08 -4.83600877e+08  6.70e+02 1.56e-01  9.05e+02    18s
#   10   5.95985036e+08 -3.20892309e+08  4.49e+02 8.48e-02  5.77e+02    19s
#   11   4.69653249e+08 -2.35191087e+08  3.41e+02 6.28e-02  4.24e+02    20s
#   12   4.24713031e+08 -1.62765198e+08  3.03e+02 4.17e-02  3.42e+02    21s
#   13   2.21481395e+08 -1.40068135e+08  1.38e+02 3.58e-02  2.02e+02    22s
#   14   1.95444075e+08 -1.22213208e+08  1.19e+02 3.15e-02  1.75e+02    22s
#   15   1.76346260e+08 -9.55246516e+07  1.06e+02 2.51e-02  1.48e+02    23s
#   16   1.45583254e+08 -7.65853450e+07  8.38e+01 2.06e-02  1.19e+02    24s
#   17   1.25784696e+08 -6.48386724e+07  7.04e+01 1.79e-02  1.02e+02    25s
#   18   1.08420863e+08 -4.82349881e+07  5.83e+01 1.42e-02  8.27e+01    26s
#   19   9.91508431e+07 -3.73156167e+07  5.23e+01 1.18e-02  7.16e+01    27s
#   86   1.21776220e+07  6.98247184e+06  2.04e+00 4.20e-04  2.63e+00    83s
#   87   1.20092930e+07  7.01979302e+06  1.96e+00 4.02e-04  2.53e+00    84s
#   88   1.18872999e+07  7.03655907e+06  1.90e+00 3.95e-04  2.46e+00    85s
#   89   1.18037834e+07  7.06892784e+06  1.86e+00 3.81e-04  2.40e+00    85s
#   90   1.16785655e+07  7.08907184e+06  1.80e+00 3.68e-04  2.33e+00    86s
#   91   1.13083886e+07  7.13836640e+06  1.64e+00 3.38e-04  2.11e+00    87s
#
# Barrier performed 91 iterations in 87.03 seconds (46.74 work units)
# Barrier solve interrupted - model solved by another algorithm
#
# Concurrent spin time: 55.96s (can be avoided by choosing Method=3)
#
# Solved with dual simplex
#
# Root relaxation: objective 7.655747e+06, 31369 iterations, 80.74 seconds (39.90 work units)
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 7655746.87    0    3          - 7655746.87      -     -   87s
# H    0     0                    1.065475e+07 7655746.87  28.1%     -   88s
# H    0     0                    9974369.5122 7655746.87  23.2%     -   89s
#      0     0 7796970.98    0    5 9974369.51 7796970.98  21.8%     -  103s
#      0     0 7797848.46    0    5 9974369.51 7797848.46  21.8%     -  107s
#      0     0 7801281.41    0    2 9974369.51 7801281.41  21.8%     -  110s
#      0     0 7801314.81    0    2 9974369.51 7801314.81  21.8%     -  113s
#      0     0 7803841.96    0    2 9974369.51 7803841.96  21.8%     -  120s
#      0     0 7804803.02    0    2 9974369.51 7804803.02  21.8%     -  123s
#      0     0 7804843.89    0    2 9974369.51 7804843.89  21.8%     -  124s
#      0     0 7804886.41    0    2 9974369.51 7804886.41  21.8%     -  124s
#      0     0 7804888.52    0    2 9974369.51 7804888.52  21.8%     -  125s
#      0     0 7804991.25    0    2 9974369.51 7804991.25  21.7%     -  132s
#      0     0 7804992.71    0    2 9974369.51 7804992.71  21.7%     -  135s
#      0     0 7805954.27    0    2 9974369.51 7805954.27  21.7%     -  138s
#      0     0 7805954.36    0    2 9974369.51 7805954.36  21.7%     -  141s
#      0     0 7805955.17    0    2 9974369.51 7805955.17  21.7%     -  143s
#      0     0 7805955.72    0    2 9974369.51 7805955.72  21.7%     -  146s
#      0     0 7805955.72    0    2 9974369.51 7805955.72  21.7%     -  151s
# H    0     0                    7807322.0084 7805955.72  0.02%     -  153s
#
# Cutting planes:
#   Cover: 1
#   MIR: 9
#   StrongCG: 1
#   Flow cover: 32
#   Flow path: 11
#
# Explored 1 nodes (36564 simplex iterations) in 156.43 seconds (130.69 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 7.80732e+06 7.80732e+06 9.97437e+06 1.06548e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.807322008449e+06, best bound 7.807322008449e+06, gap 0.0000%

# %% [markdown]
# #### Open hubs

# %%
for key in h.keys():
    if h[key].X != 0:
        print(key)
# Out:
# ANKARA
# DIYARBAKIR
# ERZURUM
# GAZIANTEP
# ISTANBUL
# IZMIR

# %% [markdown]
# ### Solution with shortest paths

# %%
#model
m = gp.Model("q2_part2")
m.ModelSense = GRB.MINIMIZE
#decision variables 
h=m.addVars(possible_hubs, name="h", vtype=GRB.BINARY)
x=m.addVars(cities, cities, possible_hubs, name="x",vtype=GRB.CONTINUOUS, lb = 0)
y=m.addVars(cities, possible_hubs, possible_hubs, name="y", vtype=GRB.CONTINUOUS, lb = 0)
z=m.addVars(cities, possible_hubs, name="z", vtype=GRB.CONTINUOUS, lb = 0)

# %%
hub_limit=m.addConstr(gp.quicksum(fixed_hub_cost[i]*h[i] for i in possible_hubs) <= 2400,"hub_cost_limit")

cons1 = m.addConstrs(
    (gp.quicksum(z[(i,k)] for k in possible_hubs) == o[i] for i in cities))

cons2 = m.addConstrs(
    (gp.quicksum(x[(i,j,l)] for l in possible_hubs) == flow.at[i,j] for i in cities for j in cities))

cons3 = m.addConstrs(
    (gp.quicksum(y[(i,k,l)] for l in possible_hubs) + 
     gp.quicksum(x[(i,j,k)] for j in cities) - 
     gp.quicksum(y[(i,l,k)] for l in possible_hubs) -
     z[(i,k)] == 0 for i in cities for k in possible_hubs))

cons4 = m.addConstrs(
    (z[(i,k)] <= o[i] * h[k] for i in cities for k in possible_hubs))

cons5 = m.addConstrs(
    (x[i,j,l] <= flow.at[i,j] * h[l] for i in cities for j in cities for l in possible_hubs))
    
m.setObjective(gp.quicksum(gp.quicksum(u.at[i,k] * z[(i,k)] for k in possible_hubs) + gp.quicksum(alpha*u_hub.at[k,l]*y[(i,k,l)] for k in possible_hubs for l in possible_hubs) + gp.quicksum(u.at[l,j] * x[i,j,l] for l in possible_hubs for j in cities) for i in cities))

# %%
m.optimize()
# Out:
# Gurobi Optimizer version 9.5.2 build v9.5.2rc0 (mac64[rosetta2])
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 551206 rows, 1069524 columns and 3195288 nonzeros
# Model fingerprint: 0x8ff67f9c
# Variable types: 1069443 continuous, 81 integer (81 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+07]
#   Objective range  [1e-04, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+07]
# Presolve removed 6642 rows and 13122 columns
# Presolve time: 3.29s
# Presolved: 544564 rows, 1056402 columns, 3175605 nonzeros
# Variable types: 1056321 continuous, 81 integer (81 binary)
#
# Deterministic concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Root barrier log...
#
# Ordering time: 0.36s
#
# Barrier statistics:
#  Dense cols : 81
#  AA' NZ     : 2.382e+06
#  Factor NZ  : 4.254e+06 (roughly 700 MB of memory)
#  Factor Ops : 3.825e+08 (less than 1 second per iteration)
#  Threads    : 5
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.35825968e+11 -1.28330758e+10  3.80e+05 6.94e-15  4.18e+05    11s
#    1   8.62485446e+10 -3.89350939e+09  2.55e+05 2.05e+01  2.16e+05    12s
#    2   3.78769982e+10 -1.76259626e+09  1.10e+05 7.04e-01  8.76e+04    13s
#    3   1.21316078e+09 -1.56754576e+09  1.25e+03 2.94e-01  2.32e+03    14s
#    4   8.98456095e+08 -6.96136464e+08  8.04e+02 8.20e-02  1.11e+03    15s
#    5   7.86268515e+08 -5.67254499e+08  6.80e+02 6.38e-02  8.97e+02    15s
#    6   6.68618612e+08 -3.91135220e+08  5.57e+02 3.94e-02  6.58e+02    16s
#    7   5.96913717e+08 -3.10446596e+08  4.86e+02 2.96e-02  5.43e+02    17s
#    8   4.45128080e+08 -2.10117224e+08  3.42e+02 2.01e-02  3.69e+02    18s
#    9   3.19472157e+08 -1.32694331e+08  2.33e+02 1.22e-02  2.42e+02    19s
#   10   2.14791544e+08 -7.51085402e+07  1.45e+02 6.66e-03  1.49e+02    20s
#   11   1.41104273e+08 -4.99733229e+07  9.00e+01 4.41e-03  9.56e+01    21s
#   12   1.12957669e+08 -4.05927799e+07  6.92e+01 3.72e-03  7.60e+01    22s
+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.986410789128e+06, best bound 6.986410789128e+06, gap 0.0000%

# %% [markdown]
# #### Open hubs

# %%
for key in y.keys():
    if y[key].X > 1:
        if h[key[1]].X == 0 or h[key[2]].X == 0:
            print("{:>50} {:>15} {:>4} {:>4}".format(str(key), round(y[key].X,3), h[key[1]].X, h[key[2]].X))
# Out:
#            ('ADIYAMAN', 'DIYARBAKIR', 'GAZIANTEP')      371790.463  1.0 -0.0
#                 ('ADIYAMAN', 'GAZIANTEP', 'ADANA')       73949.277 -0.0  1.0
#              ('ADIYAMAN', 'GAZIANTEP', 'ISTANBUL')      297841.186 -0.0  1.0
#                ('AGRI', 'DIYARBAKIR', 'SANLIURFA')      180224.828  1.0 -0.0
#                     ('AGRI', 'SANLIURFA', 'ADANA')      180224.828 -0.0  1.0
#                 ('ANTALYA', 'ANKARA', 'GAZIANTEP')      232538.946  1.0 -0.0
#             ('ANTALYA', 'GAZIANTEP', 'DIYARBAKIR')      232538.946 -0.0  1.0
#                 ('ARTVIN', 'ERZURUM', 'GAZIANTEP')       65095.689  1.0 -0.0
#                   ('ARTVIN', 'GAZIANTEP', 'ADANA')       65095.689 -0.0  1.0
#                    ('AYDIN', 'ADANA', 'GAZIANTEP')      127079.394  1.0 -0.0
#               ('AYDIN', 'GAZIANTEP', 'DIYARBAKIR')      127079.394 -0.0  1.0
#              ('BINGOL', 'DIYARBAKIR', 'GAZIANTEP')      176706.507  1.0 -0.0
#              ('BINGOL', 'DIYARBAKIR', 'SANLIURFA')       29914.539  1.0 -0.0
#                  ('BINGOL', 'GAZIANTEP', 'ANKARA')      176706.507 -0.0  1.0
#                   ('BINGOL', 'SANLIURFA', 'ADANA')       29914.539 -0.0  1.0
#              ('BITLIS', 'DIYARBAKIR', 'GAZIANTEP')       86292.551  1.0 -0.0
#                  ('BITLIS', 'GAZIANTEP', 'ANKARA')       86292.551 -0.0  1.0
#                   ('CORUM', 'ANKARA', 'GAZIANTEP')        79384.48  1.0 -0.0
#                ('CORUM', 'GAZIANTEP', 'SANLIURFA')        79384.48 -0.0 -0.0
#               ('CORUM', 'SANLIURFA', 'DIYARBAKIR')        79384.48 -0.0  1.0
#              ('DENIZLI', 'GAZIANTEP', 'SANLIURFA')      113445.033 -0.0 -0.0
#                  ('DENIZLI', 'IZMIR', 'GAZIANTEP')      113445.033  1.0 -0.0
#             ('DENIZLI', 'SANLIURFA', 'DIYARBAKIR')      113445.033 -0.0  1.0
#          ('DIYARBAKIR', 'DIYARBAKIR', 'SANLIURFA')     1128181.847  1.0 -0.0
#               ('DIYARBAKIR', 'SANLIURFA', 'ADANA')     1128181.847 -0.0  1.0
#                ('ERZURUM', 'ERZURUM', 'SANLIURFA')      321466.017  1.0 -0.0
#                  ('ERZURUM', 'SANLIURFA', 'ADANA')      321466.017 -0.0  1.0
#                ('GAZIANTEP', 'ADANA', 'SANLIURFA')      172651.865  1.0 -0.0
#           ('GAZIANTEP', 'SANLIURFA', 'DIYARBAKIR')      172651.865 -0.0  1.0
#           ('GUMUSHANE', 'DIYARBAKIR', 'SANLIURFA')       22019.039  1.0 -0.0
#                ('GUMUSHANE', 'GAZIANTEP', 'ADANA')       22019.039 -0.0  1.0
#            ('GUMUSHANE', 'SANLIURFA', 'GAZIANTEP')       22019.039 -0.0 -0.0
#             ('HAKKARI', 'DIYARBAKIR', 'SANLIURFA')       82386.853  1.0 -0.0
#               ('HAKKARI', 'GAZIANTEP', 'ISTANBUL')       82386.853 -0.0  1.0
#              ('HAKKARI', 'SANLIURFA', 'GAZIANTEP')       82386.853 -0.0 -0.0
#                 ('ISTANBUL', 'ADANA', 'GAZIANTEP')     1549258.675  1.0 -0.0
#            ('ISTANBUL', 'GAZIANTEP', 'DIYARBAKIR')     1549258.675 -0.0  1.0
#                ('KARS', 'DIYARBAKIR', 'SANLIURFA')        38358.21  1.0 -0.0
#                     ('KARS', 'SANLIURFA', 'ADANA')        38358.21 -0.0  1.0
#                ('KASTAMONU', 'ADANA', 'SANLIURFA')       49758.423  1.0 -0.0
#           ('KASTAMONU', 'SANLIURFA', 'DIYARBAKIR')       49758.423 -0.0  1.0
#                 ('KAYSERI', 'ANKARA', 'GAZIANTEP')      141971.604  1.0 -0.0
#             ('KAYSERI', 'GAZIANTEP', 'DIYARBAKIR')      141971.604 -0.0  1.0
#            ('KIRKLARELI', 'ISTANBUL', 'SANLIURFA')       43497.623  1.0 -0.0
#          ('KIRKLARELI', 'SANLIURFA', 'DIYARBAKIR')       43497.623 -0.0  1.0
#                ('KIRSEHIR', 'ANKARA', 'GAZIANTEP')       33498.736  1.0 -0.0
#             ('KIRSEHIR', 'GAZIANTEP', 'SANLIURFA')       33498.736 -0.0 -0.0
#            ('KIRSEHIR', 'SANLIURFA', 'DIYARBAKIR')       33498.736 -0.0  1.0
#                  ('KOCAELI', 'ADANA', 'GAZIANTEP')      161824.907  1.0 -0.0
#             ('KOCAELI', 'GAZIANTEP', 'DIYARBAKIR')      161824.907 -0.0  1.0
#             ('MALATYA', 'DIYARBAKIR', 'GAZIANTEP')      701367.249  1.0 -0.0
#                  ('MALATYA', 'GAZIANTEP', 'ADANA')      701367.249 -0.0  1.0
#              ('MARDIN', 'DIYARBAKIR', 'SANLIURFA')      578027.413  1.0 -0.0
#                   ('MARDIN', 'SANLIURFA', 'ADANA')      330769.924 -0.0  1.0
#                ('MARDIN', 'SANLIURFA', 'ISTANBUL')      247257.489 -0.0  1.0
#               ('SIIRT', 'DIYARBAKIR', 'GAZIANTEP')      183653.755  1.0 -0.0
#               ('SIIRT', 'DIYARBAKIR', 'SANLIURFA')       31090.634  1.0 -0.0
#                   ('SIIRT', 'GAZIANTEP', 'ANKARA')       91794.515 -0.0  1.0
#                 ('SIIRT', 'GAZIANTEP', 'ISTANBUL')       91859.239 -0.0  1.0
#                    ('SIIRT', 'SANLIURFA', 'ADANA')       31090.634 -0.0  1.0
#                    ('SINOP', 'ADANA', 'SANLIURFA')       29826.964  1.0 -0.0
#               ('SINOP', 'SANLIURFA', 'DIYARBAKIR')       29826.964 -0.0  1.0
#                   ('SIVAS', 'ANKARA', 'GAZIANTEP')      100631.897  1.0 -0.0
#                ('SIVAS', 'GAZIANTEP', 'SANLIURFA')      100631.897 -0.0 -0.0
#               ('SIVAS', 'SANLIURFA', 'DIYARBAKIR')      100631.897 -0.0  1.0
#           ('SANLIURFA', 'DIYARBAKIR', 'GAZIANTEP')      511797.961  1.0 -0.0
#             ('SANLIURFA', 'GAZIANTEP', 'ISTANBUL')      511797.961 -0.0  1.0
#                 ('VAN', 'DIYARBAKIR', 'SANLIURFA')      112050.733  1.0 -0.0
#                      ('VAN', 'GAZIANTEP', 'IZMIR')      112050.733 -0.0  1.0
#                  ('VAN', 'SANLIURFA', 'GAZIANTEP')      112050.733 -0.0 -0.0
#                  ('YOZGAT', 'ANKARA', 'GAZIANTEP')       90915.584  1.0 -0.0
#              ('YOZGAT', 'GAZIANTEP', 'DIYARBAKIR')       90915.584 -0.0  1.0
#           ('ZONGULDAK', 'GAZIANTEP', 'DIYARBAKIR')       81871.299 -0.0  1.0
#             ('ZONGULDAK', 'ISTANBUL', 'GAZIANTEP')       81871.299  1.0 -0.0
#                 ('AKSARAY', 'ANKARA', 'GAZIANTEP')       52505.461  1.0 -0.0
#              ('AKSARAY', 'GAZIANTEP', 'SANLIURFA')       52505.461 -0.0 -0.0
#             ('AKSARAY', 'SANLIURFA', 'DIYARBAKIR')       52505.461 -0.0  1.0
#                ('BAYBURT', 'ERZURUM', 'SANLIURFA')       11451.503  1.0 -0.0
#                  ('BAYBURT', 'SANLIURFA', 'ADANA')       11451.503 -0.0  1.0
#               ('KIRIKKALE', 'ANKARA', 'GAZIANTEP')       50828.886  1.0 -0.0
#           ('KIRIKKALE', 'GAZIANTEP', 'DIYARBAKIR')       50828.886 -0.0  1.0
#              ('SIRNAK', 'DIYARBAKIR', 'GAZIANTEP')      201583.773  1.0 -0.0
#              ('SIRNAK', 'DIYARBAKIR', 'SANLIURFA')       86450.552  1.0 -0.0
#                  ('SIRNAK', 'GAZIANTEP', 'ANKARA')      201583.773 -0.0  1.0
#                   ('SIRNAK', 'SANLIURFA', 'ADANA')       86450.552 -0.0  1.0
#                ('ARDAHAN', 'ERZURUM', 'SANLIURFA')       15741.193  1.0 -0.0
#                  ('ARDAHAN', 'GAZIANTEP', 'ADANA')       15741.193 -0.0  1.0
#              ('ARDAHAN', 'SANLIURFA', 'GAZIANTEP')       15741.193 -0.0 -0.0
#               ('IGDIR', 'DIYARBAKIR', 'GAZIANTEP')       37317.561  1.0 -0.0
#               ('IGDIR', 'DIYARBAKIR', 'SANLIURFA')       19856.076  1.0 -0.0
#                   ('IGDIR', 'GAZIANTEP', 'ANKARA')       37317.561 -0.0  1.0
#                    ('IGDIR', 'SANLIURFA', 'ADANA')       19856.076 -0.0  1.0
#                 ('OSMANIYE', 'ADANA', 'SANLIURFA')       60873.418  1.0 -0.0
#            ('OSMANIYE', 'SANLIURFA', 'DIYARBAKIR')       60873.418 -0.0  1.0

# %%
for key in h.keys():
    if h[key].X > 0:
        print(key)
# Out:
# ADANA
# ANKARA
# DIYARBAKIR
# ERZURUM
# ISTANBUL
# IZMIR

# %%
u_hub.at["DIYARBAKIR", "GAZIANTEP"] + u_hub.at["GAZIANTEP","ADANA"]
# Out:
# 0.0301398050512601

# %%
u_hub.at["DIYARBAKIR", "ADANA"]
# Out:
# 0.0301398050512601
